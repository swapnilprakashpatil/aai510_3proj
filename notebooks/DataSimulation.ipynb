# %% [markdown]
# # Simulate Patient Data Columns
# This notebook demonstrates how to generate the `PatientNotes`, `PatientSentiment`, and `NoShowReason` columns using the `DataSimulator` class. You can specify custom column names for each output.

# %%
# %pip install -r ../requirements.txt
# Out:
# Collecting numpy>=1.20.0
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting pandas>=1.3.0
#   Using cached pandas-2.3.0-cp310-cp310-win_amd64.whl (11.1 MB)
# Collecting scikit-learn>=1.0.0
#   Using cached scikit_learn-1.7.0-cp310-cp310-win_amd64.whl (10.7 MB)
# Collecting xgboost>=1.5.0
#   Using cached xgboost-3.0.2-py3-none-win_amd64.whl (150.0 MB)
# Collecting matplotlib>=3.4.0
#   Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
# Collecting seaborn>=0.11.0
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Collecting plotly>=5.0.0
#   Using cached plotly-6.1.2-py3-none-any.whl (16.3 MB)
# Collecting nltk>=3.6.0
#   Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Collecting transformers>=4.20.0
#   Using cached transformers-4.52.4-py3-none-any.whl (10.5 MB)
# Collecting torch>=1.10.0
#   Using cached torch-2.7.1-cp310-cp310-win_amd64.whl (216.1 MB)
# Collecting streamlit>=1.10.0
#   Using cached streamlit-1.45.1-py3-none-any.whl (9.9 MB)
# Collecting pytest>=6.0.0
#   Using cached pytest-8.4.0-py3-none-any.whl (363 kB)
# Collecting joblib>=1.0.0
#   Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Collecting imbalanced-learn>=0.8.0
#   Using cached imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Collecting wordcloud>=1.8.0
#   Using cached wordcloud-1.9.4-cp310-cp310-win_amd64.whl (299 kB)
# Collecting tqdm>=4.60.0
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting sentencepiece>=0.1.96
#   Using cached sentencepiece-0.2.0-cp310-cp310-win_amd64.whl (991 kB)
# Collecting accelerate>=0.12.0
#   Using cached accelerate-1.7.0-py3-none-any.whl (362 kB)
# Collecting evaluate>=0.3.0
#   Using cached evaluate-0.4.3-py3-none-any.whl (84 kB)
# Collecting beautifulsoup4>=4.9.0
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Collecting regex>=2022.0.0
#   Using cached regex-2024.11.6-cp310-cp310-win_amd64.whl (274 kB)
# Collecting scipy>=1.7.0
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Collecting pytest-cov>=2.12.0
#   Using cached pytest_cov-6.2.1-py3-none-any.whl (24 kB)
# Collecting jupyter>=1.0.0
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Collecting ipywidgets>=7.6.0
#   Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Collecting notebook>=6.4.0
#   Using cached notebook-7.4.3-py3-none-any.whl (14.3 MB)
# Collecting openpyxl>=3.0.0
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Collecting tabulate>=0.8.0
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from pandas>=1.3.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.58.4-cp310-cp310-win_amd64.whl (2.2 MB)
# Collecting pillow>=8
#   Using cached pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
# Requirement already satisfied: packaging>=20.0 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r ../requirements.txt (line 5)) (25.0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting narwhals>=1.15.1
#   Using cached narwhals-1.42.1-py3-none-any.whl (359 kB)
# Collecting click
#   Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Collecting requests
#   Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Collecting filelock
#   Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting tokenizers<0.22,>=0.21
#   Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Collecting huggingface-hub<1.0,>=0.30.0
#   Using cached huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Collecting safetensors>=0.4.3
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting fsspec
#   Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from torch>=1.10.0->-r ../requirements.txt (line 10)) (4.14.0)
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting packaging>=20.0
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting watchdog<7,>=2.1.5
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Collecting pyarrow>=7.0
#   Using cached pyarrow-20.0.0-cp310-cp310-win_amd64.whl (25.8 MB)
# Collecting tenacity<10,>=8.1.0
#   Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting pydeck<1,>=0.8.0b4
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Collecting blinker<2,>=1.5.0
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting toml<2,>=0.10.1
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from streamlit>=1.10.0->-r ../requirements.txt (line 11)) (6.5.1)
# Collecting altair<6,>=4.0
#   Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Collecting cachetools<6,>=4.0
#   Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting protobuf<7,>=3.20
#   Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Requirement already satisfied: colorama>=0.4 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from pytest>=6.0.0->-r ../requirements.txt (line 12)) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from pytest>=6.0.0->-r ../requirements.txt (line 12)) (1.3.0)
# Collecting pluggy<2,>=1.5
#   Using cached pluggy-1.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pygments>=2.7.2 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from pytest>=6.0.0->-r ../requirements.txt (line 12)) (2.19.1)
# Collecting tomli>=1
#   Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# Collecting iniconfig>=1
#   Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Collecting sklearn-compat<1,>=0.1
#   Using cached sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: psutil in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from accelerate>=0.12.0->-r ../requirements.txt (line 18)) (7.0.0)
# Collecting dill
#   Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Collecting xxhash
#   Using cached xxhash-3.5.0-cp310-cp310-win_amd64.whl (30 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.18-py310-none-any.whl (134 kB)
# Collecting datasets>=2.0.0
#   Using cached datasets-3.6.0-py3-none-any.whl (491 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Collecting coverage[toml]>=7.5
#   Using cached coverage-7.9.1-cp310-cp310-win_amd64.whl (215 kB)
# Collecting jupyterlab
#   Using cached jupyterlab-4.4.3-py3-none-any.whl (12.3 MB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Requirement already satisfied: ipykernel in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 24)) (6.29.5)
# Requirement already satisfied: traitlets>=4.3.1 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (5.14.3)
# Collecting jupyterlab_widgets~=3.0.15
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (8.37.0)
# Collecting widgetsnbextension~=4.0.14
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Collecting notebook-shim<0.3,>=0.2
#   Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Collecting jupyterlab-server<3,>=2.27.1
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Using cached jupyter_server-2.16.0-py3-none-any.whl (386 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Collecting jsonschema>=3.0
#   Using cached jsonschema-4.24.0-py3-none-any.whl (88 kB)
# Collecting fsspec[http]>=2021.05.0
#   Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Collecting dill
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Using cached aiohttp-3.12.13-cp310-cp310-win_amd64.whl (450 kB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Requirement already satisfied: jedi>=0.16 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.1.7)
# Requirement already satisfied: stack_data in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.6.3)
# Requirement already satisfied: decorator in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (3.0.51)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 26)) (8.6.3)
# Collecting websocket-client>=1.7
#   Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Collecting nbformat>=5.3.0
#   Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Collecting jupyter-events>=0.11.0
#   Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting anyio>=3.1.0
#   Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Collecting overrides>=5.0
#   Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting prometheus-client>=0.9
#   Using cached prometheus_client-0.22.1-py3-none-any.whl (58 kB)
# Collecting argon2-cffi>=21.1
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Collecting send2trash>=1.8.2
#   Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting pywinpty>=2.0.1
#   Using cached pywinpty-2.0.15-cp310-cp310-win_amd64.whl (1.4 MB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyzmq>=24 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 26)) (27.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 26)) (5.8.1)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Collecting async-lru>=1.0.0
#   Using cached async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting jupyter-lsp>=2.0.0
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Collecting httpx>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: setuptools>=41.1.0 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r ../requirements.txt (line 24)) (63.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 24)) (1.8.14)
# Requirement already satisfied: nest-asyncio in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 24)) (1.6.0)
# Collecting json5>=0.9.0
#   Using cached json5-0.12.0-py3-none-any.whl (36 kB)
# Collecting babel>=2.10
#   Using cached babel-2.17.0-py3-none-any.whl (10.2 MB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting mistune<4,>=2.0.3
#   Using cached mistune-3.1.3-py3-none-any.whl (53 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting bleach[css]!=5.0.0
#   Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.5 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r ../requirements.txt (line 2)) (1.17.0)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.2-cp310-cp310-win_amd64.whl (105 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting scikit-learn>=1.0.0
#   Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.7.0-cp310-cp310-win_amd64.whl (43 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.4.4-cp310-cp310-win_amd64.whl (38 kB)
# Collecting propcache>=0.2.0
#   Using cached propcache-0.3.2-cp310-cp310-win_amd64.whl (41 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting async-timeout<6.0,>=4.0
#   Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting yarl<2.0,>=1.17.0
#   Using cached yarl-1.20.1-cp310-cp310-win_amd64.whl (86 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.8.4)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.25.1-cp310-cp310-win_amd64.whl (231 kB)
# Requirement already satisfied: platformdirs>=2.5 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 26)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 26)) (310)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting fastjsonschema>=2.15
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: wcwidth in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (2.2.0)
# Requirement already satisfied: pure-eval in d:\personal\ai-admissions\semester 3\aai-510 - machine learning fundamentals and applications\final team project\aai510_3proj\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->-r ../requirements.txt (line 25)) (0.2.3)
# Collecting webcolors>=24.6.0
#   Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Collecting types-python-dateutil>=2.8.10
#   Using cached types_python_dateutil-2.9.0.20250516-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, sentencepiece, pytz, mpmath, fastjsonschema, xxhash, widgetsnbextension, websocket-client, webcolors, watchdog, urllib3, uri-template, tzdata, types-python-dateutil, tqdm, tomli, toml, tinycss2, threadpoolctl, tenacity, tabulate, sympy, soupsieve, sniffio, smmap, send2trash, safetensors, rpds-py, rfc3986-validator, rfc3339-validator, regex, pyyaml, pywinpty, python-json-logger, pyparsing, pycparser, pyarrow, protobuf, propcache, prometheus-client, pluggy, pillow, pandocfilters, packaging, overrides, numpy, networkx, narwhals, multidict, mistune, MarkupSafe, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, jsonpointer, json5, joblib, iniconfig, idna, h11, fsspec, frozenlist, fqdn, fonttools, filelock, et-xmlfile, dill, defusedxml, cycler, coverage, click, charset_normalizer, certifi, cachetools, blinker, bleach, babel, attrs, async-timeout, async-lru, aiohappyeyeballs, yarl, terminado, scipy, requests, referencing, pytest, plotly, pandas, openpyxl, nltk, multiprocess, jinja2, httpcore, gitdb, contourpy, cffi, beautifulsoup4, arrow, anyio, aiosignal, xgboost, torch, scikit-learn, pytest-cov, pydeck, matplotlib, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, huggingface-hub, httpx, gitpython, argon2-cffi-bindings, aiohttp, wordcloud, tokenizers, sklearn-compat, seaborn, jupyter-console, jsonschema, argon2-cffi, accelerate, transformers, nbformat, imbalanced-learn, datasets, altair, streamlit, nbclient, jupyter-events, evaluate, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 aiohappyeyeballs-2.6.1 aiohttp-3.12.13 aiosignal-1.3.2 altair-5.5.0 anyio-4.9.0 argon2-cffi-25.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 async-timeout-5.0.1 attrs-25.3.0 babel-2.17.0 beautifulsoup4-4.13.4 bleach-6.2.0 blinker-1.9.0 cachetools-5.5.2 certifi-2025.4.26 cffi-1.17.1 charset_normalizer-3.4.2 click-8.2.1 contourpy-1.3.2 coverage-7.9.1 cycler-0.12.1 datasets-3.6.0 defusedxml-0.7.1 dill-0.3.8 et-xmlfile-2.0.0 evaluate-0.4.3 fastjsonschema-2.21.1 filelock-3.18.0 fonttools-4.58.4 fqdn-1.5.1 frozenlist-1.7.0 fsspec-2025.3.0 gitdb-4.0.12 gitpython-3.1.44 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.33.0 idna-3.10 imbalanced-learn-0.13.0 iniconfig-2.1.0 ipywidgets-8.1.7 isoduration-20.11.0 jinja2-3.1.6 joblib-1.5.1 json5-0.12.0 jsonpointer-3.0.0 jsonschema-4.24.0 jsonschema-specifications-2025.4.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.16.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.3 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 matplotlib-3.10.3 mistune-3.1.3 mpmath-1.3.0 multidict-6.4.4 multiprocess-0.70.16 narwhals-1.42.1 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 networkx-3.4.2 nltk-3.9.1 notebook-7.4.3 notebook-shim-0.2.4 numpy-2.2.6 openpyxl-3.1.5 overrides-7.7.0 packaging-24.2 pandas-2.3.0 pandocfilters-1.5.1 pillow-11.2.1 plotly-6.1.2 pluggy-1.6.0 prometheus-client-0.22.1 propcache-0.3.2 protobuf-6.31.1 pyarrow-20.0.0 pycparser-2.22 pydeck-0.9.1 pyparsing-3.2.3 pytest-8.4.0 pytest-cov-6.2.1 python-json-logger-3.3.0 pytz-2025.2 pywinpty-2.0.15 pyyaml-6.0.2 referencing-0.36.2 regex-2024.11.6 requests-2.32.4 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.25.1 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.15.3 seaborn-0.13.2 send2trash-1.8.3 sentencepiece-0.2.0 sklearn-compat-0.1.3 smmap-5.0.2 sniffio-1.3.1 soupsieve-2.7 streamlit-1.45.1 sympy-1.14.0 tabulate-0.9.0 tenacity-9.1.2 terminado-0.18.1 threadpoolctl-3.6.0 tinycss2-1.4.0 tokenizers-0.21.1 toml-0.10.2 tomli-2.2.1 torch-2.7.1 tqdm-4.67.1 transformers-4.52.4 types-python-dateutil-2.9.0.20250516 tzdata-2025.2 uri-template-1.3.0 urllib3-2.4.0 watchdog-6.0.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.14 wordcloud-1.9.4 xgboost-3.0.2 xxhash-3.5.0 yarl-1.20.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 25.1.1
# [notice] To update, run: d:\Personal\AI-Admissions\Semester 3\AAI-510 - Machine learning Fundamentals and Applications\Final Team Project\aai510_3proj\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Fix sys.path to include the parent directory so 'src' can be imported
sys.path.append(os.path.abspath('..'))

from src.data_simulator import DataSimulator
from src.preprocessor import DataPreprocessor
from src.plots import PlotGenerator
from src import config
from src.config import INPUT_PATH, OUTPUT_PATH

# Initialize the plotting system
plotter = PlotGenerator(style='whitegrid', palette='viridis')

# Load the data using the preprocessing module
preprocessor = DataPreprocessor(config)
df = preprocessor.load_data(INPUT_PATH)

# Initialize the simulator
simulator = DataSimulator()

print("Starting data simulation...")

# Simulate and save notes with custom column names (change as needed)
simulated_df = simulator.simulate(
    input_csv=INPUT_PATH,
    output_csv=OUTPUT_PATH,
    notes_col='PatientNotes',
    sentiment_col='PatientSentiment',
    reason_col='NoShowReason'
)

print("Data simulation completed!")

# Display a sample of the generated columns
simulated_df[[
    'PatientId', 'Age', 'Gender', 'PatientNotes', 'PatientSentiment', 'NoShowReason'
]].head(10)
# Out:
# Starting data simulation...
# Data simulation completed!
# Data simulation completed!
#       PatientId  Age Gender  \
# 0  2.987250e+13   62      F
# 1  5.589978e+14   56      M
# 2  4.262962e+12   62      F
# 3  8.679512e+11    8      F
# 4  8.841186e+12   56      F
# 5  9.598513e+13   76      F
# 6  7.336882e+14   23      F
# 7  3.449833e+12   39      F
# 8  5.639473e+13   21      F
# 9  7.812456e+13   19      F
#
#                                         PatientNotes  \
# 0  Patient has a known history of hypertension. P...
# 1  Discussed men's health and cardiovascular risk...
# 2  Discussed women's health screening and prevent...
# 3  Pediatric patient. Parent/guardian present dur...
# 4  Patient has a known history of hypertension. P...
# 5  Patient has a known history of hypertension. P...
# 6  Patient previously missed appointments. Discus...
# 7  Patient previously missed appointments. Discus...
# 8  Discussed women's health screening and prevent...
# 9  Discussed women's health screening and prevent...
#
#                                     PatientSentiment  \
# 0  Patient expresses fear and anxiety about high ...
# 1  Patient is hopeful and shows no significant an...
# 2  Elderly patient expresses fear of declining he...
# 3  Patient (minor) is anxious and fearful about m...
# 4  Patient experiences stress and anxiety managin...
# 5  Patient expresses fear and anxiety about high ...
# 6  Patient is hopeful and shows no significant an...
# 7  Patient is hopeful and shows no significant an...
# 8  Patient is hopeful and shows no significant an...
# 9  Patient is hopeful and shows no significant an...
#
#                                    NoShowReason
# 0                                            NA
# 1                                            NA
# 2                                            NA
# 3                                            NA
# 4                                            NA
# 5                                            NA
# 6          Patient was anxious about the visit.
# 7  Couldn't leave home due to household duties.
# 8                                            NA
# 9                                            NA
